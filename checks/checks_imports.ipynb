# %%
import mcs
from mcs.schemas import DatasetSpec
from mcs.validation import validate_all_5specs
from mcs.provenance import ProvenanceRecord
from mcs.registry import LocalRegistry
